# %% [markdown]
# # Systems Check Assignment 1
# ## Shahbaz

# %% [markdown]
# # What I Hope to Get Out From This Class
#
# ## Learning Goals
# I am taking this class to strengthen my understanding of **data systems** and *analytical thinking*
#
# ### Key Objectives
# 1. I want to learn hands on interative data using **Object Oriented Programming**
# 2. Apply problem-solving skills to real world scenario
# 3. Understanding the golden rules to present data to **Stakeholders Impactfully**
# 4. Improve problem solving skills using technology

# %% [markdown]
# ## Why this matters to me
#
# I want to build skills that are **pratical** and *career focused*. Additionally, *I want to learn data visualisation from broader perspective.*
#
# ![Systems Checking](image/Systemschecking.png)

# %%
# Code Defining Functions

def function_name():

    def give_name():
        print("Shahbaz")
        
        give_name() 

def return_name():
    return "Shahbaz"

new_name = return_name

print(new_name())
# Out:
# Shahbaz
